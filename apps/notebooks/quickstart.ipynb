# %% [markdown]
# # Snowflake Quickstart Notebook
# Use this notebook to test connection and query data from Snowflake.

# %%
from src.db.snowflake_connection import SnowflakeConnection

conn = SnowflakeConnection.get_connection()
print('Connected' if conn else 'Connection failed')
if conn:
    conn.close()

# %%
from src.operations.select_operations import SelectOperations

SelectOperations.fetch_data('SELECT CURRENT_VERSION();')
